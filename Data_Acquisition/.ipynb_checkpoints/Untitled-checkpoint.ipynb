# %%
with open('circle.txt', 'r') as f:
    x = f.readlines()

# %%
new = []
# x = x.strip()
for line in x[10:]:
    print(line.strip())
# Out:
# [-105.82568359375, 294.61517333984375, 94.72982788085938]
#
# [-88.50666809082031, 299.64031982421875, 83.77965545654297]
#
# [-84.84979248046875, 307.5101623535156, 84.32569122314453]
#
# [-80.99645233154297, 316.1976013183594, 84.3567886352539]
#
# [-77.33319854736328, 325.0873718261719, 85.17069244384766]
#
# [-73.28828430175781, 332.7352600097656, 85.63741302490234]
#
# [-68.06554412841797, 338.8864440917969, 84.94742584228516]
#
# [-62.0988655090332, 345.0307312011719, 84.6755599975586]
#
# [-55.828617095947266, 350.7071838378906, 85.20021057128906]
#
# [-49.241512298583984, 355.46405029296875, 85.32694244384766]
#
# [-41.21950149536133, 358.89520263671875, 83.91888427734375]
#
# [-33.2812385559082, 361.556396484375, 82.27120971679688]
#
# [-25.065507888793945, 363.0730285644531, 79.49966430664062]
#
# [-16.74628257751465, 364.51922607421875, 77.20599365234375]
#
# [-9.557953834533691, 364.3921813964844, 73.83465576171875]
#
# ...

# %%
import re

# %%
for line in x[4:]:
    m = re.search('(?<=)\w+', str(line).strip())
    print(m)
# Out:
# <_sre.SRE_Match object; span=(1, 2), match='I'>
# None
# <_sre.SRE_Match object; span=(1, 2), match='P'>
# None
# <_sre.SRE_Match object; span=(1, 2), match='M'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='1'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='8'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='8'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='8'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='7'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='7'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='6'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='6'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='5'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='4'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='4'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='3'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='2'>
# None
# <_sre.SRE_Match object; span=(5, 6), match='1'>
# None
# ...
